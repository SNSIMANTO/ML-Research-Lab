# %% [markdown]
# <a href="https://colab.research.google.com/github/SNSIMANTO/ML-Research-Lab/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # .ipynb = interective python note book

# %%
print("Roadn to ML With python")
# Out:
# Roadn to ML With python

# %%
print("ABC =" , "\n" ,45 ,  ","  ,45)
# Out:
# ABC =
#  45 , 45

# %%
print(5*5,5-2)
# Out:
# 25 3

# %% [markdown]
# **VARIABLE**

# %%
number = 12345
print(number)

git=50
print("the value of git =",git)
# Out:
# 12345
# the value of git = 50

# %% [markdown]
# DATA Type Printing

# %%
#printing different types of values

n1=12  #this is int type

n2=12.648  #this is float type

sum= n1+n2   # float? yes !!
print(type(sum),sum)
print(type(n1))
print(type(n2))
# Out:
# <class 'float'> 24.648
# <class 'int'>
# <class 'float'>

# %% [markdown]
# **Printing perticular number after  . **

# %%
number = 12.438732645824695

print("{:.3f}".format(number))   #3f= will print 3 numbers after .

print("{:.5f}".format(number))   #5f= will print 5 number after  .
# Out:
# 12.439
# 12.43873

# %% [markdown]
# Taking input in python

# %%
#input function always take string value

number1= input("Enter the 1st number:")
number2= input("Enter the 2nd number:")
sum=number1+number2
print("The sum of number1 and number2 is :",sum)
# Out:
# Enter the 1st number:3
# Enter the 2nd number:4
# The sum of number1 and number2 is : 34

# %%
number1= input("Enter a number:")
number2= input("Enter another number:")

print(" the sum of both number is:", number1+number2)
# Out:
# Enter a number:3
# Enter another number:4
#  the sum of both number is: 34

# %% [markdown]
# INPUT STRING BUT THE OUTPUT IS INT

# %%
# Take input as string
num_str = input("Enter a number: ")

# Convert string to integer
num_int = int(num_str)

# Print the integer value
print("Integer value is:", num_int)
# Out:
# Enter a number: 12
# Integer value is: 12
